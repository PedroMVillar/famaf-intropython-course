# %% [markdown]
# ![CursoIntroPython.jpg](attachment:a2b7434c-b92b-4c1f-82eb-1847d581c12e.jpg)

# %% [markdown]
# # 1. Introducción a la sintaxis de Python
# ----------------------------
#
# Este curso está dirigido para aquellos que se estén iniciando en el mundo de la programación y que desean aprender un lenguaje y que tiene aplicacion científica, entre otras.
#
# ## Qué es Python
#
# Python es un lenguaje de programación de alto nivel moderno, de propósito general, orientado a objetos; creado por  [Guido van Rossum](https://es.wikipedia.org/wiki/Guido_van_Rossum) en la decada de los 90.
#
# Su nombre se lo debe a [Monte Python](https://es.wikipedia.org/wiki/Monty_Python), grupo británico de seis humoristas de quienes Guido era fanático.

# %% [markdown]
# ### 1.1 Características generales de Python:
#
# - **Lenguaje limpio y sencillo**: código fácil de leer e intuitivo, fácil de aprender sintaxis minimalista, la capacidad de mantenimiento escala bien con el tamaño de los proyectos.
#
# - **Lenguaje expresivo**: Menos líneas de código, menos errores, más fácil de mantener.
#
# - **Dinámicamente tipado**: No es necesario definir el tipo de variables, argumentos de función o tipos de retorno.
#
# - **Gestión automática de memoria**: no es necesario asignar y desasignar explícitamente memoria para variables y matrices de datos. No hay errores de pérdida de memoria.
#
# ### 1.2 __Ventajas:__
#
# - Un lenguaje multiparadigma (orientación a objetos, imperativo y funcional.)
#
# - Un lenguaje multipropósito (Usado para hacer una web o hacer cálculo matemático, un script para que te automatice una tarea de sistemas o un framework REST)
#
# - La principal ventaja es la facilidad de programación, minimizando el tiempo necesario para desarrollar, depurar y mantener el código.
#
# - Un lenguaje bien diseñado que alienta muchas buenas prácticas de programación:
#     - Programación modular y orientada a objetos, buen sistema de empaquetación y reutilización de código. Esto a menudo resulta en un código más transparente, mantenible y sin errores.
#     - Documentación estrechamente integrada con el código.
#
# - Una gran biblioteca estándar, y una gran colección de paquetes adicionales.
#
# - Un lenguaje multiplataforma, dado que un código escrito en Python, puede correr en Lunix, Windos, Mac, etc. Incluyendo todas sus librerías. Otros códigos tambien lo son, pero en Pyhton tenemos una aspecto muy poderosos, que son lo gráficos.
#
#
# ### 1.3 __Desventajas:__
#
# - Dado que Python es un lenguaje de programación interpretado y de tipo dinámico, la ejecución del código python puede ser lenta en comparación con los lenguajes de programación compilados estáticamente mecanografiados, como Fortran, C y C++
#
# - Algo descentralizado, con diferentes entornos, paquetes y documentación distribuidos en diferentes lugares. Puede hacer más difícil comenzar.

# %% [markdown]
# ### 1.4 Python 2 vs Python 3
# Actualmente hay dos versiones de Python. La rama 2.7 (actualmente la version 2.7.13) y la rama 3 (actualmente 3.9). Todas las bibliotecas científicas de Python funcionan con ambas versiones. Pero ¡Python 3 es aún más fácil y es el que permanecerá a futuro!
#
# A partir de Enero del 2020 la rama 2.7 dejó de recibir actualizaciones y parches, la mayoría de librerías ya han sido movidas a la versión 3 así que esta será la versión que se utilizará en este curso.

# %% [markdown]
# ![Python_Org.png](DownloadPython2022.png)

# %% [markdown]
# ___The PSF___  The Python Software Foundation is the organization behind Python.
#
# Visiten la página
# https://www.python.org/

# %% [markdown]
# ## 2. Instalación de Python
#
# ### 2.2 Instalación en Linux
#
# ##### Python 3 está instalado por defecto en la distribución Linux Ubuntu 18.xx.
# Entonces necesitaremos instalar el paquete python3-pip usando el siguiente comando. También instalará las dependencias requeridas, agilizando así el proceso.
#
# Tanto para macOS y Linux__ es muy conveniente instalar __PIP__.
# PIP es un administrador de descargas de librerias para Python.
#
# En __Linux - Ubuntu 22__ viene Instalado por defecto el Python 3.
#
# No obstante podemos instalarlo mediante __PIP__
#
# 1. En primer lugar, actualizar la lista de paquetes, usando el siguiente comando. Puedes ejecutar este comando como administrador o como usuario normal con privilegios sudo.
#
# En ese caso, debes añadir sudo al comando antes de ejecutar la actualización.
#
# Puede que según la _version_ de _linux_, este comando varíe
#
# ___$ sudo apt update___
#
# 2. Luego instalamos PIP
#
# ___$ apt install python3-pip___
#
# 3. Podemos verificar las versiones de cada uno utilizando los siguientes comandos pip:
#
# ___$ pip3 --version___
#
#
# ___$ python3 -V___
#
# En linux suele estar instañlado Pyhton 2, como Python y PIP 2 como PIP, lo que algunas veces suele producir errores.
#
# _________________________________________________
#  en __Windows__ es conveniente usar la Play Store para instalarlo y además instala librerías o bibliotécas básicas muy importante.

# %% [markdown]
# ### 2.3 Uso de Python en la linea de comando
# En una terminal o ventana de comando, debemos escribir Python o Python3, de esa manera se activará el intérprete del mismo.

# %%
! python3 --version
! pip3 --version
# Out:
# Python 3.10.12
# pip 23.2.1 from /home/edgardo/.local/lib/python3.10/site-packages/pip (python 3.10)

# %% [markdown]
# El intérprete nos permitira escribir lineas comandos, desde las más simples como operaciones artirméticas, hasta poder escribir programas.

# %%
4 + 3
# Out:
# 7

# %%
4 * 3
# Out:
# 12

# %%
4 ** 3
# Out:
# 64

# %%
64**(1/3)
# Out:
# 3.9999999999999996

# %% [markdown]
# ## 3.0 Jupyter Notebook - JupyterLab
# https://jupyter.org/
#
# Jupyter (___IPython___) es un __shell interactivo__ (__IDE__) que añade funcionalidades extra al modo interactivo incluido con Python, como resaltado de líneas y errores mediante colores, una sintaxis adicional para el shell, autocompletado mediante tabulador de variables, módulos y atributos; entre otras funcionalidades.

# %% [markdown]
# ### 3.1 Notebook de Jupyter
#
# El cuaderno Notebook de Jupyter está basado en la web y es interactivo. Un notebook en Jupyter es un documento __JSON__ que contiene una lista ordenada de entradas / salidas las cuales pueden tener __código, texto, imagenes y rich media__.
#
# Los notebooks de Jupyter pueden ser convertidos a otros formatos de archivos como HTML, presentaciones de diapositivas, LaTeX, PDF, Python, etc.
#
# Esta será nuestra herramienta de trabajo durante el curso. Esto que estás leyendo ahora no es más que un notebook de Jupyter, que como diremos luego además de código puede contener texto e imágenes. Pero veamos primero cómo funciona.
#
# ______

# %% [markdown]
# Para abrir los Notebook, en la carpeta de interés, desde una terminal o ventana comando, debemos escribir ___Jupyter Notebook___ y darle enter, de esta manera, en el Navegador por default que tengamos, se abrirá una Home Page en HTML, donde mostrará todo el contenido de la carpeta.
#
# Los archivos con terminacion ___ipynb___ son lo programas o documentos ___json___ que son abiertos en una nueva poágina en nuestro navegador.
# __________

# %% [markdown]
# Se puede crear un nuevo cuaderno en cualquier momento, desde el panel de control o mediante la opción de menú Archivo ‣ Nuevo desde un cuaderno activo. El nuevo cuaderno se crea dentro del mismo directorio y se abrirá en una nueva pestaña del navegador. También se reflejará como una nueva entrada en la lista de cuadernos en el dashboard.
#
# Al crear un notebook o al abrir uno nuevo se abre la interfaz de Jupyter propiamente dicha donde ya podemos empezar a trabajar. Es similar a un intérprete, pero está dividida en __celdas__. Las celdas pueden contener, código, texto, imágenes...
#
# Cada celda de código está marcada por la palabra __In [<n>]__ y están numeradas. Tan solo tenemos que escribir el código en ella y hacer click arriba en Cell -> Run, el triángulo __("Run cell")__ o usar el atajo __shift + Enter__. El resultado de la celda se muestra en el campo __Out [<n>]__, también numerado y coincidiendo con la celda que acabamos de ejecutar. Esto es importante, como ya veremos luego.

# %% [markdown]
# Para documentar nuestros notebooks en Jupyter esto se logra usando el lenguaje de marcado de texto __Markdown__. Las celdas correspondientes se denominan celdas Markdown. El lenguaje de Markdown proporciona una forma sencilla de realizar este marcado de texto, es decir, especificar qué partes del texto deben enfatizarse (cursivas), negritas, listas de formularios, etc.
#
# Si en la barra superior seleccionas Markdown (o usas el atajo __Shift-M__) en lugar de Code puedes escribir texto.
#
# También puedes escribir ecuaciones matematicas en Latex y mucho más. Esto es una herramienta muy potente para explicar a alguien o a uno mismo lo que tu código hace, para hacer un informe, un trabajo, escribir en un blog...
#
# Podemos mover las celdas de un lugar a otro de este modo, arriba y abajo.

# %% [markdown]
# ### 3.2 Instalación de Jupyter Notebook
# **Jupyter** (https://docs.jupyter.org/en/latest/)
#
# Para instalar en Ubuntu, debemos hacer
#
# Si no tenemos instalado __PIP__ debemos hacer
# __$ sudo apt install python3-pip__
#
# Luego actualizarlo
# __$ sudo pip3 install --upgrade pip__
#
# y posteriormente instalamos Jupyter Lab
# ___$ sudo pip3 install jupyterlab___
#
# y para usarlo, debemos hacer:
#
# ___$ jupyter-lab___
#
# o
# ___$ jupyter lab___
# o
#
# ___$ sudo jupyter-lab___
#
# en Windows
#
# ___pip install jupyterlab___

# %%
# En una terminal escribir 
# jupyter-lab
# jupyterlab
# jupyter lab

# %% [markdown]
# ### 3.3 Ver y ejecutar una script en Jupyter
# Una __script__ es un código escrito en python, se le suele dar el nombre de __programa o script__, dependiendo del objetivo del uso del mismo. Pero eso es irrelevante.
#
# Ahora veremos un __script__ en nuestro notebook.
# Para ver el contenido de nuestro script vamos a usar el comando cat (Linux) (o more para Window), en este caso el archivo que contiene el script se llama script1.py. El cual fue escrito con anterioridad, con un editor de texto simple en ASCCI, por ejemplo vi, gedit, notebook, notebook++, etc.

# %%
# !cat script_00.py
#!more script_00.py
# Out:
# ### Introducir un numero por teclado y decir si es par o impar
#
# num = int(input('Introduzca un numero: '))
#
# if num % 2 == 0:
#    print('Par')
# else:
#    print('Impar')

# %% [markdown]
# Para ejecutar nuestro __script__ vamos a usar un comado mágico del notebook :

# %%
# %run script_00.py
# Out:
# Introduzca un numero:  34
# Par

# %% [markdown]
# ## Comencemos a programar
# Comenzamos a escribir unas lineas de python en nuestro __Notebook__

# %%
# esto es una linea de comando en Python
print('Bienvenidos al curso de Python!')
# Out:
# Bienvenidos al curso de Python!

# %% [markdown]
# #### Comentarios

# %%
print("Hola 'Mundo'")
# Out:
# Hola 'Mundo'

# %%
# Los comentarios son muy útiles para los programadores 
# así podemos entender el código de otras personas
# y además permite documentar el código

print("Debo comentar mi codigo")
# print("Esto no se imprimirá")

""" Esto tambien es un comentario
de multiples lineas"""

"""
Y esto también es una forma de realizar comenatrios
pueden ser varios renglones

puedo dejar renglones en blanco
"""

print("Hola")
# Out:
# Debo comentar mi codigo
# Hola

# %% [markdown]
# Los comentarios tambien son usados como para señalar el tipo de codificación que se esta usando. De forma predeterminada, los archivos de origen de Python se tratan como si estuvieran codificados en __UTF-8__. En esa codificación, aunque la biblioteca estándar solo utiliza caracteres __ASCII__ para los __identificadores__. Por ejemplo, para declarar que se va a usar la codificación de __Windows-1252__, la primera línea de su archivo de código fuente debería ser:

# %%
# -*- coding: cp1252 -*-

# %% [markdown]
# __Windows-1252__ o __CP-1252__ es una codificación de caracteres del alfabeto latino, usada por defecto cuando unicode no se usa en los componentes oficiales de Microsoft Windows en inglés y en algunos lenguajes occidentales.
#
# Es una versión en la que el código de páginas de Windows está en los paquetes de LaTeX, el cual se refiere como ansinew.

# %% [markdown]
# ## Fundamentos de Python
# ----------------------------

# %% [markdown]
# ### Tipos numéricos
# Python al igual que otros lenguajes posee tipos numericos como  `int `,  `float ` y sus respectivas operaciones básicas.

# %% [markdown]
# ### Este programa realiza varias operaciones con expresiones matemáticas y cadenas de texto.
#
# #### Expresión matemática

# %%
#Esto es una expresión
5 * 10 - (7 - 2)/5 + 3.14
# Out:
# 52.14

# %% [markdown]
# ### Operación de división por cero
# Resultado: ZeroDivisionError
# Comentario: Esta operación generará un error de división por cero.
# Qué pasará si...

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-0106664d39e8> in <module>
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ![](attachment:horror.png)

# %% [markdown]
# ### Operación de división entre enteros
# > Comentario: La división entre enteros nos dará un numero real ( `float `) :

# %%
8/5
# Out:
# 1.6

# %% [markdown]
# ### Operación de división floor
# La división floor (usando el símbolo `//` ) siempre nos retorna la parte entera de la división.
# > Comentario: La división floor (usando el símbolo `//`) siempre nos retorna la parte entera de la división.

# %%
19 // 3
# Out:
# 6

# %% [markdown]
# ### Operador de residuo
# > Comentario: El operador `%` nos retorna el residuo de la división.

# %%
19 % 4
# Out:
# 3

# %% [markdown]
# ### Con Números complejos
# > Comentario: Además Python 3 posee un tipo especial `complex`

# %%
12 + 7j
# Out:
# (12+7j)

# %% [markdown]
# ### Operaciones con números complejos
# > Comentario: Ejemplo de operaciones con números complejos.

# %%
(2j) * (3j)
# Out:
# (-6+0j)

# %% [markdown]
# ### Otras operaciones matemáticas
# > Comentario: Ejemplo de operaciones matemáticas.

# %%
45 * 3
# Out:
# 135

# %% [markdown]
# ### Operador de potencia
# > Comentario: Python también posee un operador para la potencia.

# %%
6**2
# Out:
# 36

# %% [markdown]
# ### Operaciones con números complejos y potencia
#
# > Comentario: Ejemplo de operaciones con números complejos y potencia.

# %%
(2j)**2
# Out:
# (-4+0j)

# %% [markdown]
# ### Funciones integradas
# Python tambien posee funciones integradas ([__built-in functions__](https://docs.python.org/3/library/functions.html)) muy útiles.
#
# > Comentario: Ejemplo de la función `abs()` que retorna el valor absoluto de un número.

# %%
abs(-5) # Valor absoluto
# Out:
# 5

# %% [markdown]
# ### Función `abs()` con número complejo
# > Comentario: La función `abs()` también funciona con números complejos.

# %%
abs(4+3j) # Modulo
# Out:
# 5.0

# %% [markdown]
# ### Función `round()`
# > Comentario: La función `round()` redondea el número al entero más cercano.

# %%
round(3.124)
# Out:
# 3

# %%
round(9.501)
# Out:
# 10

# %% [markdown]
# ### Función `max()`
#
# > Comentario: La función `max()` retorna el valor más grande de una secuencia de números.

# %%
max(5,1,6,-2,10,7)
# Out:
# 10

# %% [markdown]
# ### Función `min()`
#
# > Comentario: La función `min()` retorna el valor más pequeño de una secuencia de números.

# %%
min(2,5,7,1,-1,0)
# Out:
# -1

# %% [markdown]
# ### Función `sorted()`
#
# > Comentario: La función `sorted()` ordena una secuencia de números en orden ascendente.

# %%
listadoOrdenado = sorted([2,5,7,1,-1,0], reverse=True)
# print(listadoOrdenado)

# %% [markdown]
# ### Conversión de tipos
#
# > Comentario: Ejemplo de conversión de decimal a entero.

# %%
int(23.12)
# Out:
# 23

# %%
int(12.99)
# Out:
# 12

# %%
float(12.99)
# Out:
# 12.99

# %%
float(3)
# Out:
# 3.0

# %% [markdown]
# ### Conversión de tipos
#
# > Comentario: Ejemplo de conversión de entero a decimal.

# %%
3
# Out:
# 3

# %% [markdown]
# ### Conversión de tipos en operaciones aritméticas
# > Comentario: Ejemplo de una operación aritmética.

# %%
(2*1.5)/2
# Out:
# 1.5

# %% [markdown]
# ### Conversión de tipo complejo
#
# > Comentario: Ejemplo de conversión de decimal a número complejo.

# %%
complex(2.1)
# Out:
# (2.1+0j)

# %% [markdown]
# ### El Separador de Miles
# > Comentario: Ejemplo del formato de separador de miles.

# %%
x = 1,234,567.89
f = x * 2
x
# Out:
# (1, 234, 567.89)

# %%
f
# Out:
# (1, 234, 567.89, 1, 234, 567.89)

# %%
x = 1234567.89
x
# Out:
# 1234567.89

# %% [markdown]
# ### El Separador de Miles
#
# > Comentario: Ejemplo de formato de separador de miles con la función `format()`.

# %%
y = '{:,}'.format(x)
y*2
# Out:
# '1,234,567.891,234,567.89'

# %%
print(y)
# Out:
# 1,234,567.89

# %% [markdown]
# ### la función print() y un formato simple
#
# > Comentario: Ejemplo de cálculo simple.

# %%
print(100 * 1.0/3)
# Out:
# 33.333333333333336

# %%
print("%.5f%%" % (100 * 1.0/3))
# Out:
# 33.33333%

# %% [markdown]
# > Comentario: Ejemplo de formato de porcentaje usando `%.5f`.

# %%
p = 10000 * 1.0/3

# %%
print("%.5f%%" % (p))
# Out:
# 3333.33333%

# %%
print("%.5f" % (p))
# Out:
# 3333.33333

# %%
x = 2.3455667
print("%.8f%%" % (100 * x))
# Out:
# 234.55667000%

# %% [markdown]
# > Ejemplo de formato de porcentaje usando `f"{prob:.4%}"`.

# %%
prob = 1.0/3.0
print(f"{prob:.4%}")
# Out:
# 33.3333%

# %%
prob = 1.0/3.0
print(f"{prob:.4}")
# Out:
# 0.3333

# %%
print(f"{prob:.4}")
# Out:
# 0.3333

# %%
print(f"{x:.4%}")
# Out:
# 234.5567%

# %% [markdown]
# ### Función help()
# > Comentario: La función `help()` muestra información de ayuda sobre una función.

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %% [markdown]
# ### Variables
#
# Una variable es como una caja en la memoria de la computadora en donde se puede almacenar un valor.
# Al igual que otros lenguajes la asignación de una variable en Python funciona con el operador __`=`__.
#
# Luego podemos utilizarlas como si se tratase de un valor literal, incluso operarlas entre otras variables y volver a asignarles un valor en cualquier momento.

# %%
x = 2.13

# %% [markdown]
# ### Comentario: Ejemplo de impresión de una variable.

# %%
print(x)
# Out:
# 2.13

# %% [markdown]
# ### Función type()
# > Comentario: Nos permite saber que tipo de datos es la variable `x`

# %%
type(x)
# Out:
# float

# %% [markdown]
# > Comentario: Ejemplo de asignación de un nuevo valor a la variable.
#
# Si asignamos nuevamente otro numero a la misma variable, esta cambia y se le asigna el nuevo valor

# %%
x = 322

# %%
x
# Out:
# 322

# %% [markdown]
# > Comentario: Ejemplo de impresión del tipo de la variable.

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Asiganción múltiple de variables
# > Comentario: Ejemplo de asignación múltiple de variables.

# %%
a, b = 2, 10 
print(a,", ", b)
# Out:
# 2 ,  10

# %% [markdown]
# ### Función print()
#
# La función __print()__ nos permite imprimir en consola una variable,expresiones, etc...
# **`print()`** es una función muy útil ya que nos permite imprimir el valor de una variable o el resultado de una comparación.

# %%
num = 322
print(num)
# Out:
# 322

# %% [markdown]
# ### operación aritmética dentro de una función
# > Comentario: Ejemplo de operación con variables en la función print().

# %%
print(a * b)
# Out:
# 20

# %% [markdown]
# > Comentario: Ejemplo de error al usar una variable no definida.
# Si invocamos una variable, que no esta previamente definida, nos dará un error

# %%
#print(k)
print(a)
print(b)
print("c")
# Out:
# 2
# 10
# c

# %% [markdown]
# > Comentario: Ejemplo de operación con una variable y posterior impresión.

# %%
num = num + 1 
print(num)
# Out:
# 323

# %% [markdown]
# ### Nombre de variables

# %% [markdown]
# Existen reglas a la hora de declarar variables, entre ellas tenemos:
# ![validos.png](attachment:validos.png)

# %% [markdown]
# Además existen palabras reservadas que no pueden ser usadas como nombres para variables
# ![tokens.png](attachment:tokens.png)

# %% [markdown]
# ### Imprimiendo en pantalla

# %% [markdown]
# Un ejemplo del uso de la función _print()_
# Esta función es muy importante pues necesitamos que el código Python nos muestre los resultados.

# %%
a = 'perro'
b = "gato"

# %%
print(a)
print(b)
# Out:
# perro
# gato

# %% [markdown]
# veamos otra función intrinseca de Python, es decir una función que es propia del lenguaje.
# Esta función se llama _type()_

# %%
print(type(b))
b = 3.5j
print(type(b))
# Out:
# <class 'str'>
# <class 'complex'>

# %% [markdown]
# ### Impresión con formatos

# %%
nombre = "Lionel"
print(f"Hola {nombre}")
# Out:
# Hola Lionel

# %% [markdown]
# ### Otros formatos

# %% [markdown]
# El método  string **`str.format()`** de Python, permite hacer sustituciones de variables y formatear valores. Esto le permite concatenar elementos juntos dentro de una cadena a través del formato posicional.
# > Comentario: podemos incluir resultados dentro de un texto

# %%
print("Estoy haciendo {} cursos en verano en el año {}".format(4, 2023))
# Out:
# Estoy haciendo 4 cursos en verano en el año 2023

# %% [markdown]
# > Podemos referenciar el orden de las variables con sus índices (Los indices empiezan en 0)

# %%
print("Carlos tiene un {1}, un {0} y cero {2}!".format("perro", "gato", "tortuga"))
# Out:
# Carlos tiene un gato, un perro y cero tortuga!

# %%
print("Carlos tiene un {}, un {} y cero {}!".format("perro", "gato", "tortuga"))
# Out:
# Carlos tiene un perro, un gato y cero tortuga!

# %%
print("Carlos tiene un {1}, un {0} y cero {2}!".format("perro", "gato", "tortuga"))
# Out:
# Carlos tiene un gato, un perro y cero tortuga!

# %% [markdown]
# > comenatario: Tambien podemos usar variables numéricas

# %%
nroCreditos = 28
print("Creo que llevará {} créditos el otro curso!".format(nroCreditos))
# Out:
# Creo que llevará 28 créditos el otro curso!

# %% [markdown]
# > El orden importa a la hora de usar __`format()`__

# %%
'{} {} {}'.format('a', 'b', 'c')
# Out:
# 'a b c'

# %%
'{2} {1} {0}'.format('a', 'b', 'c')
# Out:
# 'c b a'

# %%
'{color} {n} {x}'.format(n=10, x=1.5, color='blue')
# Out:
# 'blue 10 1.5'

# %% [markdown]
# ### Número de digitos en el formato del print()
# > Si queremos imprimir un numero decimal y queremos precisar el numero de digitos a imprimir usamos:
# __%(tamaño total).(numero de decimales)f__

# %%
print("%.9f" % 1321.123456789)
# Out:
# 1321.123456789

# %%
print("%18.15f" % 9788.213318204967192)
# Out:
# 9788.213318204967436

# %% [markdown]
# ### Tipo Booleano
# El álgebra binaria fue desarrollada por George Bool
# ![GeorgeBoole.png](attachment:7baceef2-53a4-4f6b-ba65-c95c9c149345.png)
#
# Por ello a las variables que se utilizan esta álgebra, se les llamma __booleanos__.
#
# Los tipos booleanos son un tipo de dato en programación que solo puede tener dos valores posibles: Verdadero (True) o Falso (False). Estos valores son fundamentales para la lógica y control de flujo en los programas.
#
# En Python, el tipo booleano se representa por los literales True y False. Estos valores son objetos únicos del lenguaje y son utilizados para evaluar condiciones en expresiones lógicas. Por ejemplo:

# %%
x = True
y = False

# %% [markdown]
# > Python soporta tambien un tipo especial que solo adquiere dos valores y eso son los booleanos:
#
# - __True__
# - __False__
#
# > Tambien tenemos operaciones del algebra booleana como:
# - __or__ operador `o`
# - __and__ operador `y`
# - __not__ operador `no`

# %%
print(True or False)
print(True and False)
print(False and False)
print(True and True)
# Out:
# True
# False
# False
# True

# %%
print(not True)
print(not False)
# Out:
# False
# True

# %% [markdown]
# Podemos usar operadores para comparar, tales como (__==, != ,<, >, <=, >=__)

# %%
a = 15
b = 10
c = 15

# %%
print(a == b)
# Out:
# False

# %%
print(a == c)
# Out:
# True

# %%
print(a < b)
print(a >= b)
print(a != c)
# Out:
# False
# True
# False

# %% [markdown]
# __________________________________________
# ¿Que sucede con los números complejos?

# %%
print(2j < 3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-93f3c686852b> in <module>
# ----> 1 print(2j < 3j)
#
# TypeError: '<' not supported between instances of 'complex' and 'complex'

# %% [markdown]
# Ups!! qué sucedió?
# Como sabrán los complejos no se pueden ordenar.
# ______________________________

# %% [markdown]
# Tambien podemos realizar operaciones combinadas

# %%
((4 < 6) and (5 >= 8)) or (4 != 7)
# Out:
# True

# %% [markdown]
# Tambien podemos realizar operaciones combinadas

# %%
((4 < 6) and (5 >= 8)) or (4 != 7)
# Out:
# True

# %% [markdown]
# ### Tipo String o Cadenas de Caracteres

# %% [markdown]
# Además de los enteros, flotantes y complejos; existen otros tipos muy importantes como los strings __(cadenas de caracteres).__

# %%
name = "Joaquina"

# %%
print(name)
# Out:
# Joaquina

# %% [markdown]
# Con el comando `type` podemos observar que tipado tiene una determinada variable

# %%
type(name)
# Out:
# str

# %% [markdown]
# Este tipo especial tiene algunas operaciones como:

# %%
second_name = "Martinez"
print(name + second_name)
# Out:
# JoaquinaMartinez

# %% [markdown]
# Esta operación es llamada concatenación, y vemos que sale todo pegado.
# Para separarlos hacemos ...

# %%
# Para separarlo ;)
print(name + " " + second_name)
# Out:
# Joaquina Martinez

# %% [markdown]
# Tambien podemos multiplicar una cadena por un número entero (__ENTERO__).

# %%
print(name * 3)
# Out:
# JoaquinaJoaquinaJoaquina

# %%
print(name * 3.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-8681a1efd912> in <module>
# ----> 1 print(name * 3.2)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %% [markdown]
# No podemos multiplicar cadenas de caracteres por flotantes, tampoco por números complejos.

# %% [markdown]
# Si podemos convertir numeros a cadenas, por ejemplo:

# %%
x = 5
print(type(x), x)
x = str(x)
print(type(x), x)
# Out:
# <class 'int'> 5
# <class 'str'> 5

# %%
#print("Hola " + str(x))
print("Hola " + x)
# Out:
# Hola 5

# %% [markdown]
# Podemos usar ciertos caracteres especiales de escape como `\n` (Salto de línea) o  `\t` (tabulador)

# %%
s = "Python es un lenguaje increíble\nFacil de usar"
print(s)
# Out:
# Python es un lenguaje increíble
# Facil de usar

# %%
other_string = "Esta\tes\tuna\tcadena\tseparada\tpor\ttabs"
print(other_string)
# Out:
# Esta	es	una	cadena	separada	por	tabs

# %% [markdown]
# Ahora vamos a utilizar una función muy especial para poder obtener una cadena del teclado. La función a utilizar se llama __input()__

# %%
print("Bienvenidos a nuestro primer programa")
print("Ingrese su nombre por favor")
name = input()
print('Su nombre es : ' + name)
# Out:
# Bienvenidos a nuestro primer programa
# Ingrese su nombre por favor
#  Edgardo
# Su nombre es : Edgardo

# %%
name = "Juan José"

# %%
print("Bienvenido " + name)
print("Tu nombre tiene " + str(len(name)) + " letras")
print("Gracias por usar este sistema")
# Out:
# Bienvenido Juan José
# Tu nombre tiene 9 letras
# Gracias por usar este sistema

# %% [markdown]
# Dentro de input tambien podemos escribir una cadena

# %%
age = input("Ingrese su edad: ")
print("Usted tendrá " + str(int(age)+5) + " años dentro de 5 años")
# Out:
# Ingrese su edad:  45
# Usted tendrá 50 años dentro de 5 años

# %% [markdown]
# Ahora por qué dijimos que las cadenas son un tipo especial?...

# %%
# Definamos una cadena

cadena = "Susti"

primera_letra = cadena[0]

print(primera_letra)
# Out:
# S

# %% [markdown]
# ¿Qué significa ese [0]? ...
# [0] es el índice o index, pero... Qué es un índice?? D:

# %% [markdown]
# ![array.png](attachment:array.png "Estructura de una cadena")

# %% [markdown]
# Un string o cadena es un tipo especial.

# %%
#Si queremos hallar el tamaño de una cadena usamos la función len()
dog_name = "Picho"
print(str(len(dog_name)))
# Out:
# 5

# %%
dog_name[2]
# Out:
# 'c'

# %% [markdown]
# ¿Qué pasó?... Rex tiene 3 letras pero los arrays empiezan en cero, es decir que la ultima letra será el índice 2.

# %%
dog_name[1]
# Out:
# 'i'

# %%
dog_name[0]
# Out:
# 'P'

# %% [markdown]
# ¿Cómo imprimo la última letra de una cadena sin saber su longitud?

# %%
dog_name[-1]
# Out:
# 'o'

# %% [markdown]
# Si deseo imprimir las 3 primeras letras de una cadena lo que debo hacer es:

# %%
animal = "murcielago"
animal[0:3]
# Out:
# 'mur'

# %% [markdown]
# Para las 3 ultimas puedo usar:

# %%
animal[-3:]
# Out:
# 'ago'

# %% [markdown]
# ### Slicing en las cadenas
# El __slicing__ es una capacidad de las cadenas que devuelve un subconjunto o subcadena utilizando dos índices [inicio:fin]:
#
# - El primer índice indica donde empieza la subcadena (se incluye el carácter).
# - El segundo índice indica donde acaba la subcadena (se excluye el carácter).

# %%
cadena_prueba = "Veranito cordobés"
cadena_prueba[0:5]
# Out:
# 'Veran'

# %%
materia = "físicacuantica"
materia[8:]
# Out:
# 'antica'

# %%
materia[:8]
# Out:
# 'físicacu'

# %% [markdown]
# Si en el slicing no se indica un índice se toma por defecto el principio y el final (incluídos)

# %%
materia[:]
# Out:
# 'físicacuantica'

# %%
palabra = "unidades_atómicas"

# %%
palabra[:6]+palabra[6:]
# Out:
# 'unidades_atómicas'

# %% [markdown]
# Una propiedad de las cadenas es que no se pueden modificar esta propiedad se llama __inmutabilidad__. Si intentamos reasignar un carácter, no nos dejará:

# %%
palabra[0] = "a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-7b71c995d020> in <module>
# ----> 1 palabra[0] = "a"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Pero podemos usar la concatenación si queremos cambiar la primera letra

# %%
palabra = "a" + palabra[1:]

# %%
print(palabra)
# Out:
# anidades_atómicas

# %% [markdown]
# ### Ahora veamos algunas métodos que podemos usar en strings:
#
# > Qué es un __Método__ en Python
# > Un método es una función que «pertenece a» un objeto.
# > Por ejemplo, los objetos __lista__ tienen métodos llamados _append_, _insert_, _remove_, _sort_, y así sucesivamente.

# %% [markdown]
# #### Método  `index() `
# que pertenece a los objetos tipo __string__

# %%
algunTexto =  "Universidad Nacional de Córdoba"
algunTexto.index("dad") # Retorna el indice donde empieza "dad"
# Out:
# 8

# %%
type(algunTexto)
# Out:
# str

# %% [markdown]
# #### Método  `find()`

# %%
algunTexto2 = "Facultad de Matemática, Astronomía, Física y Computación"
algunTexto2.find('Físi') # el método find() tambien nos retorna el índice pero en caso de no encontrarlo nos da -1
# Out:
# 36

# %% [markdown]
# #### Método  `upper()`
# Para convertir toda la cadena a mayuscula

# %%
ciencia = "AsTROnomiA"
print(ciencia.upper()) # Convierte toda la cadena a mayuscula
# Out:
# ASTRONOMIA

# %% [markdown]
# #### Método  `lower()`
# Para convertir toda la cadena a minuscula

# %%
print(ciencia.lower()) # Convierte toda la cadena a minuscula
# Out:
# astronomia

# %% [markdown]
# #### Método  `capitalize()`
# Esta función nos retorna la primera letra en mayuscula las demás en minuscula

# %%
print(ciencia.capitalize()) # Nos retorna la primera letra en mayuscula las demás en minuscula
# Out:
# Astronomia

# %% [markdown]
# #### Método  `startswith()`
# El método __startswith__ nos dará un booleando como respuesta, __True__ si es que empieza con __"str"__

# %%
# El método startswith nos dará un booleando como respuesta, True si es que empieza con "str"
oracion = "Python es un lenguaje muy usado."
print(oracion.startswith("Py"))    # Puede ser Python, Pyt, Pyth, Pytho, etc..
print(oracion.startswith("Cy"))
# Out:
# True
# False

# %% [markdown]
# #### Método  `endswith()`
# El método endswith nos dará un booleando si es que finaliza con "str"

# %%
# El método endswith nos dará un booleando si es que finaliza con "str"
print(oracion.endswith("usado."))
print(oracion.endswith("muy"))
# Out:
# True
# False

# %% [markdown]
# #### Método  `count()`
# El método count() se utiliza para averiguar cuántas veces se repite una cadena o char en un string dado.
# También puede especificar el índice inicial y final.

# %%
# El método count() se utiliza para averiguar cuántas veces se 
# repite una cadena o char en un string dado. 
# También puede especificar el índice inicial y final.

oracion.count("e")
# Out:
# 3

# %% [markdown]
# Nos cuenta cuantos _string_ estan entre el rango de caracteres [15, 33]

# %%
oracion.count("e",15,33)
# Out:
# 1

# %% [markdown]
# #### Método  `replace()`
# Replace (old, new) ee utiliza para reemplazar la parte de la cadena por una nueva.

# %%
# Replace (old, new) ee utiliza para reemplazar la parte de la cadena por una nueva.

oracion.replace("Python","Javascript")
# Out:
# 'Javascript es un lenguaje muy usado.'

# %% [markdown]
# #### Método  `join()`
# El método join nos permite unir cadenas o iterables

# %%
# El método join nos permite unir cadenas o iterables
test = "_"
test2 = "Córdoba"
result = test.join(test2)
print(result)
# Out:
# C_ó_r_d_o_b_a

# %% [markdown]
# #### Método  `split()`
# El método split nos permite separar una cadena en base a una cadena

# %%
# El método split nos permite separar una cadena en base a una cadena
final = 'Tal vez,  deberías, seguir estudiando'.split(',')
print(final)
# Out:
# ['Tal vez', '  deberías', ' seguir estudiando']
